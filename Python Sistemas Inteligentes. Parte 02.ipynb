# %% [markdown]
# # Estructuras de datos
#
# Hasta ahora hemos restringido nuestros ejemplos a los tipos de datos simples incorporados, por ejemplo, `cadena`, `int` y `float`. En la práctica, los programas utilizarán *estructuras de datos* para reunir los datos en paquetes útiles. Por ejemplo, en lugar de representar un vector `r` de longitud 3 usando tres floats `u`, `v` y `w`, podríamos representarlo
# representarlo como una lista de flotantes, `r = [u, v, w]`. Del mismo modo, si queremos almacenar los nombres de los alumnos de un grupo de laboratorio, en lugar de una variable de cadena para cada alumno, podríamos trabajar con una lista de nombres, por ejemplo

# %%
lab_group0 = ["Sarah", "John", "Joe", "Emily"]
lab_group1 = ["Roger", "Rachel", "Amer", "Caroline", "Colin"]

# %% [markdown]
# Se trata de una construcción mucho más potente porque podemos realizar operaciones sobre una lista, como comprobar su longitud (número de alumnos en un grupo de laboratorio), ordenar los nombres de la lista en orden alfabético y añadir o eliminar nombres. Incluso podríamos hacer una lista de listas, por ejemplo

# %%
lab_groups = [lab_group0, lab_group1]

# %% [markdown]
# para reunir todos los grupos de laboratorio en una lista *anidada*.
#
# Las estructuras de datos son particularmente útiles cuando se pasan datos a las funciones. Digamos que queremos una función que imprima los nombres de los estudiantes de un determinado grupo de laboratorio. En lugar de pasar el nombre de cada estudiante (con diferentes grupos que tienen diferentes números de miembros), podemos pasar sólo la lista de miembros del grupo de laboratorio a la función.
# Del mismo modo, podemos desarrollar una función que calcule el producto punto entre dos vectores de longitud arbitraria, pasando a la función sólo los dos vectores en lugar de cada componente.
#
# Veremos tres estructuras de datos incorporadas en Python que se utilizan habitualmente. Son:
#
# - `lista`
# - `tupla`
# - `dict` (diccionario)

# %% [markdown]
# # Listas
#
# Una `lista` es una secuencia de datos. Un `array` en la mayoría de los otros lenguajes es un concepto similar, pero las listas de Python son más generales que la mayoría de los arrays ya que pueden contener una mezcla de tipos. Una lista se construye usando corchetes:

# %%
lab_group0 = ["Sarah", "John", "Joe", "Emily", "Quang"]
print("Lab group members: {}".format(lab_group0))
print("Size of lab group: {}".format(len(lab_group0)))

print("Check the Python object type: {}".format(type(lab_group0)))
# Out:
# Lab group members: ['Sarah', 'John', 'Joe', 'Emily', 'Quang']
# Size of lab group: 5
# Check the Python object type: <class 'list'>

# %%
my_list = []

# %%
my_list = ["Oliver"]*5
print(my_list)
# Out:
# ['Oliver', 'Oliver', 'Oliver', 'Oliver', 'Oliver']

# %% [markdown]
# ## Iterar sobre listas
#
# Hacer un bucle sobre cada elemento de una lista (o más generalmente de una secuencia) se llama *iterar*. Iteramos sobre los miembros del grupo del laboratorio usando la sintaxis:

# %%
for member in lab_group0:
    print(member)
# Out:
# Sarah
# John
# Joe
# Emily

# %% [markdown]
# Digamos que queremos iterar sobre los nombres de los miembros del grupo de laboratorio, y obtener la posición
# de cada miembro en la lista. Para ello utilizamos `enumerar`:

# %%
for n, member in enumerate(lab_group0):
    print(n, member)
# Out:
# 0 Sarah
# 1 John
# 2 Joe
# 3 Emily

# %% [markdown]
# En lo anterior, n es la posición en la lista y miembro es la 𝑛ª entrada en la lista. A veces necesitamos saber la posición, en cuyo caso enumerar es útil. Sin embargo, cuando es posible es preferible utilizar una iteración "simple". Tenga en cuenta que Python cuenta desde cero - utiliza la indexación basada en cero.

# %%
# Ejemplo básico de lista
list = ['uno','dos','tres']

for i in list:
  print(i)
  
list.remove('uno')
list.append('cuatro')

for i in list:
  print('new',i)
# Out:
# uno
# dos
# tres
# new dos
# new tres
# new cuatro

# %% [markdown]
# ## Manipulación de listas
#
# Hay muchas funciones para manipular listas. Puede ser útil ordenar la lista:

# %%
lab_group0.sort()
for member in lab_group0:
    print(member)
# Out:
# Emily
# Joe
# John
# Quang
# Sarah

# %% [markdown]
# En lo anterior, `sort` se conoce como un 'método' de una `lista`. Realiza una ordenación "in situ", es decir, "lab_group0" se ordena, en lugar de crear una nueva lista con entradas ordenadas (para esto último usaríamos "sorted(lab_group0)`, que devuelve una nueva lista). Más adelante, cuando lleguemos al diseño orientado a objetos, hablaremos de los métodos.
#
# Con las listas podemos añadir y eliminar estudiantes:

# %%
# Remove the second student (indexing starts from 0, so 1 is the second element)
lab_group0.pop(1)
print(lab_group0)

# Add new student "Josephine" at the end of the list
lab_group0.append("Josephine")
print(lab_group0)
# Out:
# ['Sarah', 'Joe', 'Emily']
# ['Sarah', 'Joe', 'Emily', 'Josephine']

# %%
lab_group1 = ["Roger", "Rachel", "Amer", "Caroline", "Colin"]

lab_group = lab_group0 + lab_group1
print(lab_group)
# Out:
# ['Emily', 'John', 'Quang', 'Sarah', 'Josephine', 'Roger', 'Rachel', 'Amer', 'Caroline', 'Colin']

# %%
lab_groups = [lab_group0, lab_group1]
print(lab_groups)

print("---")

print("Print each lab group (name and members):")
for i, lab_group in enumerate(lab_groups):
    print(i, lab_group)
# Out:
# [['Emily', 'John', 'Quang', 'Sarah', 'Josephine'], ['Roger', 'Rachel', 'Amer', 'Caroline', 'Colin']]
# ---
# Print each lab group (name and members):
# 0 ['Emily', 'John', 'Quang', 'Sarah', 'Josephine']
# 1 ['Roger', 'Rachel', 'Amer', 'Caroline', 'Colin']

# %% [markdown]
# ## Indexación
#
# Las listas almacenan los datos en orden, por lo que es posible "indexar" una lista utilizando un número entero (esto le resultará familiar a cualquiera que haya utilizado C), por ejemplo

# %%
first_member = lab_group0[0]
third_member = lab_group0[2]
print(first_member, third_member)
# Out:
# Emily Quang

# %%
for i in range(len(lab_group0)):
    print(lab_group0[i])
# Out:
# Emily
# John
# Quang
# Sarah
# Josephine

# %% [markdown]
# Indices start from zero, and run through to (length - 1).

# %%
# Two vectors of length 4. Indexing can be useful for numerical computations. We use it here to compute the dot product of two vectors:
x = [1.0, 3.5, 7.2, 8.9]
y = [-1.0, 27.1, 1.0, 6]

# calcular el producto escalar
dot_product = 0.0
for i in range(len(x)):
    dot_product += x[i]*y[i]

print(dot_product)
# Out:
# 154.45000000000002

# %%
lab_group0 = ["Sarah", "John", "Joe", "Emily"]
lab_group1 = ["Roger", "Rachel", "Amer", "Caroline", "Colin"]
lab_groups = [lab_group0, lab_group1]

# %%
group = lab_groups[0]
print(group)

name = lab_groups[1][2]
print(name)
# Out:
# ['Sarah', 'John', 'Joe', 'Emily']
# Amer

# %% [markdown]
# ## Heterogeneidad (listas con tipos mixtos)
#
# Las listas de Python son estructuras de datos heterogéneas - esto significa que pueden almacenar tipos mixtos, por ejemplo

# %%
mixed_list = ["Adam", 2 + 4j, 1.0, 4]
for entry in mixed_list:
    print(entry, type(entry))
# Out:
# Adam <class 'str'>
# (2+4j) <class 'complex'>
# 1.0 <class 'float'>
# 4 <class 'int'>

# %% [markdown]
# ## Comprensión de listas (avanzada)
#
# Una poderosa construcción en los lenguajes modernos, incluyendo Python, es la *comprensión de listas*. Es una forma de construir sucintamente listas a partir de otras listas. Puede ser muy útil, pero debe aplicarse con sensatez ya que a veces puede ser difícil de leer. Al final de este cuaderno hay un ejercicio de ampliación opcional que utiliza la comprensión de listas.
#
# Supongamos que tenemos una lista de números y queremos crear una nueva lista que eleve al cuadrado cada número de la lista original y le sume 5. Utilizando la comprensión de la lista:

# %%
x = [4, 6, 10, 11]
y = [a*a + 5 for a in x]

print(x)
print(y)
# Out:
# [4, 6, 10, 11]
# [21, 41, 105, 126]

# %% [markdown]
# Para entender el significado, lea la declaración de izquierda a derecha.
#
# Como otro ejemplo, digamos que tenemos una lista de nombres y queremos
#
# - construir una nueva lista de nombres que contenga sólo los nombres con más de 5 caracteres; y
# - para estos nombres queremos añadir un punto al final.
#
# Utilizando la comprensión de la lista:

# %%
lab_group1 = ["Roger", "Rachel", "Amer", "Caroline", "Colin"]
group = [name + "." for name in lab_group1 if len(name) > 5]

print(lab_group1)
print(group)
# Out:
# ['Roger', 'Rachel', 'Amer', 'Caroline', 'Colin']
# ['Rachel.', 'Caroline.']

# %% [markdown]
# ## Tuplas
#
# Las tuplas están estrechamente relacionadas con las listas. La principal diferencia es que una tupla no puede ser modificada después de ser creada.
# En la jerga informática, es *inmutable*.
#
# Para algo que no debe cambiar después de ser creado, como un vector de longitud tres con entradas fijas, una tupla es más apropiada que una lista. Es más "seguro" en este caso ya que no puede ser modificado accidentalmente en un programa. El hecho de ser inmutable ("sólo lectura") también permite optimizar la velocidad de las implementaciones.
#
# Para crear una tupla, hay que utilizar paréntesis. Digamos que en una universidad a cada estudiante se le asigna una habitación, y las habitaciones están numeradas. A la estudiante "Laura" se le asigna la habitación 32:

# %%
room = ("Laura", 32)
print("Room allocation: {}".format(room))
print("Length of entry: {}".format(len(room)))
print(type(room))
# Out:
# Room allocation: ('Laura', 32)
# Length of entry: 2
# <class 'tuple'>

# %% [markdown]
# Podemos iterar sobre tuplas de la misma manera que con las listas,

# %%
# Iterate over tuple values
for d in room:
    print(d)
# Out:
# Laura
# 32

# %%
# Index into tuple values
print(room[1])
print(room[0])
# Out:
# 32
# Laura

# %% [markdown]
# ## Conjuntos

# %%
lista = ['uno','dos','tres','tres']
conjunto = set(lista)
print(conjunto)

print('\'uno\' pertenece al conjunto {}'.format('uno' in conjunto))
print('\'cuatro\' pertenece al conjunto {}'.format('cuatro' in conjunto))
# Out:
# {'dos', 'uno', 'tres'}
# 'uno' pertenece al conjunto True
# 'cuatro' pertenece al conjunto False

# %% [markdown]
# # Diccionarios (mapas)
#
# En la sección anterior hemos utilizado una lista de tuplas para almacenar las asignaciones de habitaciones. Si quisiéramos encontrar qué habitación se le ha asignado a un estudiante en particular, tendríamos que iterar a través de la lista y comprobar cada nombre. Para una lista muy grande, esto podría no ser muy eficiente.
#
# Hay una forma mejor de hacerlo, utilizando un "diccionario" (o a veces llamado "mapa"). Hemos utilizado la indexación (con enteros) en listas y tuplas para acceder directamente a una entrada específica. Esto funciona si conocemos el índice de la entrada que nos interesa. Pero, para una lista de habitaciones, identificamos a los individuos por su nombre en lugar de un conjunto contiguo de enteros. Utilizando un diccionario, podemos construir un "mapa" desde los nombres (las *claves*) hasta los números de habitación (los *valores*).
#
# Un diccionario de Python (`dict`) se declara con llaves:

# %%
room_allocation = {"Adrian": None, "Laura": 32, "John": 31, "Penelope": 28, "Fraser": 28, "Gaurav": 19}
print(room_allocation)
print(type(room_allocation))
# Out:
# {'Adrian': None, 'Laura': 32, 'John': 31, 'Penelope': 28, 'Fraser': 28, 'Gaurav': 19}
# <class 'dict'>

# %% [markdown]
# Cada entrada está separada por una coma. Para cada entrada tenemos una 'clave', que va seguida de dos puntos, y luego el 'valor'. Observe que en el caso de Adrian hemos utilizado `None` para el valor, que es una palabra clave de Python para "nada" o "vacío".
#
# Ahora, si queremos saber qué habitación se ha asignado a Fraser, podemos consultar el diccionario por la clave:

# %%
frasers_room = room_allocation["Fraser"]
print(frasers_room)
# Out:
# 28

# %% [markdown]
# Si intentamos utilizar una clave que no existe en el diccionario, Python dará un error (lanzará una excepción). Si no estamos seguros de que una clave esté presente, podemos comprobarlo:

# %%
print("Fraser" in room_allocation)
print("Frasers" in room_allocation)
# Out:
# True
# False

# %%
print("Fraser" in room_allocation)
print("Frasers" in room_allocation)
# Out:
# True
# False

# %% [markdown]
# Tenga en cuenta que el orden de las entradas impresas en el diccionario es diferente del orden de entrada. Esto se debe a que un diccionario almacena los datos de forma diferente a una lista o tupla. Las listas y las tuplas almacenan las entradas "linealmente" en la memoria
# (trozos contiguos de memoria), por lo que podemos acceder a las entradas por índice. Los diccionarios utilizan un tipo de almacenamiento diferente que nos permite realizar búsquedas mediante una "clave".
#
# Hasta ahora hemos utilizado una cadena como clave, lo cual es habitual. Sin embargo, podemos utilizar casi cualquier tipo como clave, y podemos mezclar tipos. Por ejemplo, podríamos querer "invertir" el diccionario de asignación de habitaciones para crear un mapa de habitación a nombre:

# %%
# Create empty dictionary
room_allocation_inverse = {}

# Build inverse dictionary to map 'room number' -> name 
for name, room_number in room_allocation.items():
    # Insert entry into dictionary
    room_allocation_inverse[room_number] = name

print(room_allocation_inverse)
# Out:
# {None: 'Adrian', 32: 'Laura', 31: 'John', 28: 'Fraser', 19: 'Gaurav'}

# %% [markdown]
# Ahora podemos preguntar quién está en la habitación 28 y quién en la 29. No todas las habitaciones están ocupadas, por lo que debemos incluir una comprobación de que el número de habitación es una clave en nuestro diccionario:

# %%
rooms_to_check = [28, 29]

for room in rooms_to_check:
    if room in room_allocation_inverse:
        print("Room {} is occupied by {}.".format(room, room_allocation_inverse[room]))
    else:
        print("Room {} is unoccupied.".format(room))
# Out:
# Room 28 is occupied by Fraser.
# Room 29 is unoccupied.

# %% [markdown]
# ### Resumen Diccionarios

# %%
str2num = {'uno':1, 'dos':2, 'tres':3}
num2str = { 1:'uno', 2:'dos', 3:'tres'}

print('uno -> {}'.format(str2num['uno']))
print('1 -> {}'.format(num2str[1]))

print('Todos los items de str2num')
for key, value in str2num.items():
  print('\t{} -> {}'.format(key, value))
# Out:
# uno -> 1
# 1 -> uno
# Todos los items de str2num
# 	uno -> 1
# 	dos -> 2
# 	tres -> 3

# %%
print("---> Accedemos a una clave que no existe usando el método 'get'")

print(str2num.get('cuatro'))

print("---> Si accedemos a una clave que no existe usando con [] se produce un error")
try:
  print(str2num['cuatro'])
except KeyError:
  print('La clave no existe')
# Out:
# ---> Accedemos a una clave que no existe usando el método 'get'
# None
# ---> Si accedemos a una clave que no existe usando con [] se produce un error
# La clave no existe

# %% [markdown]
# #Clases y objetos
#
#
# Como ejemplo sencillo, consideremos una clase que contenga los apellidos y el nombre de una persona:

# %%
class PersonName:
    def __init__(self, surname, forename):
        self.surname = surname  # Attribute
        self.forename = forename  # Attribute
        
    # This is a method
    def full_name(self):
        "Return full name (forename surname)"
        return self.forename + " " + self.surname

    # This is a method
    def surname_forename(self, sep=","):
        "Return 'surname, forename', with option to specify separator"
        return self.surname + sep + " " + self.forename

# %% [markdown]
# Antes de diseccionar la sintaxis de esta clase, vamos a utilizarla.
# Primero creamos un objeto (una instanciación) de tipo `NombrePersona`:

# %%
name_entry = PersonName("Bloggs", "Joanna")
print(type(name_entry))
# Out:
# <class '__main__.PersonName'>

# %% [markdown]
# Primero probamos los atributos:

# %%
print(name_entry.surname)
print(name_entry.forename)
# Out:
# Bloggs
# Joanna

# %% [markdown]
# A continuación, probamos los métodos de la clase:

# %%
name = name_entry.full_name()
print(name)

name = name_entry.surname_forename()
print(name)

name = name_entry.surname_forename(";")
print(name)
# Out:
# Joanna Bloggs
# Bloggs, Joanna
# Bloggs; Joanna

# %% [markdown]
# Diseccionando la clase, ésta es declarada por
# ```python
# class PersonName:
# ```
# Luego tenemos lo que se conoce como el *intialiser*:
# ```python
#     def __init__(self, surname, forename):
#         self.surname = surname
#         self.forename = forename
# ```
# Esta es la 'función' que se llama cuando creamos un objeto, es decir, cuando usamos `nombre_entrada = NombrePersona("Bloggs", "Joanna")`. La palabra clave `self` se refiere al objeto en sí mismo - puede llevar tiempo
# desarrollar una comprensión de `self`. El inicializador en este caso almacena el apellido y el nombre de la persona (atributos). Puedes comprobar cuándo se llama al inicializador insertando una sentencia print.
#
# Esta clase tiene dos métodos:
# ```python
#     def full_name(self):
#         "Return full name (forname surname)"
#         return self.forename + " " + self.surname
#
#     def surname_forename(self, sep=","):
#         "Return 'surname, forname', with option to specify separator"
#         return self.surname + sep + " " + self.forename
# ```
# Estos métodos son funciones que hacen algo con los datos de la clase. En este caso, a partir del nombre y los apellidos
# devuelven el nombre completo de la persona, formateado de diferentes maneras.

# %% [markdown]
# # Operadores
#
# Los operadores como `+`, `-`, `*` y `/` son en realidad funciones - en Python son la abreviatura de funciones con
# los nombres `__add__`, `__sub__`, `__mul__` y `__truediv__`, respectivamente. Añadiendo estos métodos a una clase, podemos definir lo que deben hacer los operadores matemáticos.

# %% [markdown]
# ## Matemáticas mezcladas
#
# Digamos que queremos crear nuestros propios números con sus propias operaciones. Como un simple (y muy tonto) ejemplo,
# decidimos que queremos cambiar la notación de forma que "`*`" signifique división y "`/`" signifique multiplicación.
#
# Para cambiar "`*`" y "`/`" para nuestros números especiales, creamos una clase para representar nuestros números especiales, y
# le damos sus propias funciones `__mul__` y `__truediv__`.
# También proporcionaremos el método `__repr__(self)` - este es llamado cuando usamos la función `print`.

# %%
class crazynumber:
    "A crazy number class that switches the mutliplcation and division operations"
    
    # Initialiser
    def __init__(self, x):
        self.x = x  # This is an attribute

    # Define multiplication (*) (this is a method)
    def __mul__(self, y):
        return crazynumber(self.x/y.x)

    # Define the division (/) (this is a method)
    def __truediv__(self, y):
        return crazynumber(self.x*y.x)
    
    # This is called when we use 'print' (this is a method)
    def __repr__(self):
        return str(self.x)  # Convert type to a string and return

# %% [markdown]
# > *Nota:* los nombres de los métodos `__mul__`, ` __truediv__`, `__repr__`, etc, no deben ser llamados directamente. Ellos
# > son asignados por Python a operadores (`*` y `/` en los dos primeros casos). El método `__repr__` se llama entre bastidores cuando se utiliza `print`.
#
# Ahora creamos dos objetos `crazynumber`:

# %%
u = crazynumber(10)
v = crazynumber(2)

# %% [markdown]
# Since we have defined * to be division, we expect u*v to be equal to 5 igualmente u/5 es 20:

# %%
a = u*v  # This will call '__mul__(self, y)'
print(a)  # This will call '__repr__(self)'

b = u/v
print(b)
# Out:
# 5.0
# 20

# %% [markdown]
# Al proporcionar métodos, hemos definido cómo deben interpretarse los operadores matemáticos.

# %% [markdown]
# ## Pruebas de igualdad
#
# Anteriormente hemos utilizado versiones de bibliotecas de funciones de ordenación, y hemos visto que son mucho más rápidas que nuestras propias implementaciones. ¿Qué pasa si tenemos una lista de objetos propios que queremos ordenar? Por ejemplo,
# podríamos tener una clase `EstudianteEntrada`, y luego tener una lista con un objeto `EstudianteEntrada` para cada estudiante.
# Las funciones de ordenación incorporadas no pueden saber cómo queremos ordenar nuestra lista.
#
# Otro caso es si tenemos una lista de números, y queremos ordenarla de acuerdo a una regla personalizada.
#
# Las funciones de ordenación incorporadas no se preocupan por los detalles de nuestros datos. Lo único en lo que se basan
# son *comparaciones*, por ejemplo los operadores `<`, `>` y `==`. Si equipamos nuestra clase con operadores de comparación
# podemos utilizar las funciones de ordenación incorporadas.

# %% [markdown]
# ### Ordenación personalizada
#
# Digamos que queremos ordenar una lista de números de forma que todos los números pares aparezcan antes que los impares, pero que por lo demás se aplique la regla de ordenación habitual. No queremos escribir nuestra propia función de ordenación. Podemos hacer esta ordenación personalizada creando nuestra propia clase para contener un número y equipándola con los operadores `<`, `>` y `==`.
# Las funciones correspondientes a los operadores son
#
# - `__lt__(self, other)` (menos que `other`, `<`)
# - `__gt__(self, other)` (mayor que `other`, `>`)
# - `__eq__(self, other)` (igual a `other`, `==`)
#
# Las funciones devuelven `Verdadero` o `Falso`.

# %% [markdown]
# A continuación se muestra una clase para almacenar un número que obedece a nuestras reglas de ordenación personalizadas:

# %%
class MyNumber:

    def __init__(self, x):
        self.x = x  # Store value (attribute)
        
    # Custom '<' operator (method)
    def __lt__(self, other):
        if self.x % 2 == 0 and other.x % 2 != 0:  # I am even, other is odd, so I am less than                   
            return True
        elif self.x % 2 != 0 and other.x % 2 == 0:  # I am odd, other is even, so I am not less than 
            return False
        else:
            return self.x < other.x  # Use usual ordering of numbers

    # Custom '==' operator (method)
    def __eq__(self, other):
        return self.x == other.x

    # Custom '>' operator (method)
    def __gt__(self, other):
        if self.x % 2 == 0 and other.x % 2 != 0:  # I am even, other is odd, so I am not greater                    
            return False
        elif self.x % 2 != 0 and other.x % 2 == 0:  # I am odd, other is even, so I am greater                    
            return True
        else:
            return self.x > other.x  # Use usual ordering of numbers

    # This function is called by Python when we try to print something   
    def __repr__(self):
        return str(self.x)

# %% [markdown]
# Podemos realizar algunas pruebas sencillas sobre los operadores (insertar sentencias print en los métodos si quieres
# verificar a qué función se llama)

# %%
x = MyNumber(4)
y = MyNumber(3)
print(x < y)  # Expect True (since x is even and y is odd)
print(y < x)  # Expect False
# Out:
# True
# False

# %% [markdown]
# Ahora intentamos aplicar la función de ordenación de listas incorporada para comprobar que la lista ordenada obedece a nuestra
# regla de ordenación personalizada:

# %%
# Create an array of random integers
x = np.random.randint(0, 200, 10)

# Create a list of 'MyNumber' from x (using list comprehension)
y = [MyNumber(v) for v in x]

# This is the long-hand for building y
#y = []
#for v in x:
#    y.append(MyNumber(v))

# Use the built-in list sort method to sort the list of 'MyNumber' objects
y.sort()
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14912/3265351406.py in <module>
#       1 # Create an array of random integers
# ----> 2 x = np.random.randint(0, 200, 10)
#       3
#       4 # Create a list of 'MyNumber' from x (using list comprehension)
#       5 y = [MyNumber(v) for v in x]
#
# NameError: name 'np' is not defined

# %% [markdown]
# Sin modificar el algoritmo de ordenación, hemos aplicado nuestra propia ordenación. Enfoques como éste son una característica de la computación orientada a objetos. Los algoritmos de ordenación ordenan los objetos, y los objetos simplemente necesitan los operadores de comparación. Los algoritmos de ordenación no necesitan conocer los detalles de los objetos.

# %% [markdown]
# # Usando los métodos mágicos
#
# Los métodos especiales de Python que comienzan y terminan con doble guión bajo (`__`) son métodos *mágicos*. Corresponden a operadores especiales, típicamente operadores matemáticos como `*`, `/`, `<`, `==`, etc.
#
# Son métodos estándar en el sentido de que pueden ser llamados directamente sobre un objeto, pero este no es su uso previsto.
# Utiliza los operadores en su lugar. A continuación se muestra un ejemplo.

# %%
class SomePair:
    def __init__(self, x, y):
        self.x = x  # Store value (attribute)
        self.y = y  # Store value (attribute)

    # '==' operator (note that it has a return value)
    def __eq__(self, other):
        return self.x == other.x and self.y == other.y
    
a = SomePair(23, 2)
b = SomePair(23, 5)

# Check for equality using ==
print(a == b)

# Check for equality using __eq__ (no se recomienda, importante)
print(a.__eq__(b))
# Out:
# False
# False

# %% [markdown]
# No es necesario que un objeto tenga definidas todas las funciones mágicas, sólo las que vaya a utilizar. Si intentas utilizar un operador que no está definido obtendrás un error.
